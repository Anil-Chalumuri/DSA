# %% [markdown]
# <p align="center">
#   <a href="https://www.youtube.com/@codeverra" target="_blank">
#     <img src="https://yt3.ggpht.com/2Gd6X4kYDMGVb8SXGIFS_SewyEcaNiQZfQeC2sIVMF_92nqyCSgjvItpGxzOyEofi7KUOVxQbA=s600-c-k-c0x00ffffff-no-rj-rp-mo" alt="CodeVerra Channel" width="300"/>
#   </a>
# </p>
#
#
#
# <p align="center">
#   <a href="https://www.youtube.com/playlist?list=PLo8TPLc6QbB_1SrUdxiXj7xASrEa_M2XQ" target="_blank">
#     <img src="https://i.ytimg.com/pl_c/PLo8TPLc6QbB_1SrUdxiXj7xASrEa_M2XQ/studio_square_thumbnail.jpg?sqp=CJb1vMkG-oaymwEICNYGEOADSFqi85f_AwYI__m8yQY=&rs=AOn4CLB7nLx67D4R3V2ScnHy4sOJjwaBOQ" alt="CodeVerra Channel" width="300"/>
#   </a>
# </p>
#
#
#
# [Visit the CodeVerra YouTube channel](https://www.youtube.com/@codeverra)

# %% [markdown]
# # Arrays and Strings

# %% [markdown]
# ## Two Sum

# %% [markdown]
# ## Leetcode 344. Reverse String

# %%
def reverse_string(s ):
  reversed_string = []

  while s:
    reversed_string.append(s.pop())


  return "".join(reversed_string)

input = "hello"
reverse_string(["h","e","l","l","o"])
# Out:
# 'olleh'

# %%
input.split(" ")
# Out:
# ['hello']

# %% [markdown]
# ## Leetcode 125. Valid Palindrome

# %%
s = "A man, a plan, a canal: Panama"

s.lower()
# Out:
# 'a man, a plan, a canal: panama'

# %%
def check_palindrome(s):
  filtered_string = "".join([x.lower() for x in s if x.isalnum()])
  return filtered_string == filtered_string[::-1]
# Out:
# True

# %% [markdown]
# # Two Pointer Approach

# %% [markdown]
# ### 11. Container With Most Water
#
# You are given an integer array height of length n. There are n vertical lines drawn such that the two endpoints of the ith line are (i, 0) and (i, height[i]).
#
# Find two lines that together with the x-axis form a container, such that the container contains the most water.
#
# Return the maximum amount of water a container can store.
#
# Notice that you may not slant the container.

# %%
class Solution:
    def maxArea(self, height: List[int]) -> int:
        '''

        initialise a left and right pointer to both ends
        calculate the area = (right - left) * min(height[left], height[right])

        then move the left or right whichever is lower
        calculate the area again and keep the higher area
        '''
        max_area = 0
        left = 0
        right = len(height) - 1

        while left < right:
            area = (right - left) * min(height[left], height[right])
            max_area = max(area, max_area)
            # if area > max_area:
            #     max_area = area

            ## we will move either the left or right pointer
            if height[left] < height[right]:
                left = left + 1
            else:
                right = right - 1

        return max_area

# %% [markdown]
# ### 977. Squares of a Sorted Array
#
# Given an integer array nums sorted in non-decreasing order, return an array of the squares of each number sorted in non-decreasing order.
#
#
#
# ```Example 1:
#
# Input: nums = [-4,-1,0,3,10]
# Output: [0,1,9,16,100]
# Explanation: After squaring, the array becomes [16,1,0,9,100].
# After sorting, it becomes [0,1,9,16,100].
# Example 2:
#
# Input: nums = [-7,-3,2,3,11]
# Output: [4,9,9,49,121]
# ```

# %%
class Solution:
    def sortedSquares(self, nums: List[int]) -> List[int]:

        res_array = []
        left =0
        right = len(nums) - 1

        while left <= right:
            if nums[right]**2 > nums[left]**2:
                res_array.insert(0, nums[right]**2) ## this is O(n) operation. Bad Practice !! We can append and then reverse!!
                right = right - 1

            else:
                res_array.insert(0, nums[left] ** 2)
                left = left + 1

        return res_array


class Solution:
    def sortedSquares(self, nums: List[int]) -> List[int]:

        res_array = []
        left =0
        right = len(nums) - 1

        while left <= right:
            if nums[right]**2 > nums[left]**2:
                res_array.append( nums[right]**2)
                right = right - 1

            else:
                res_array.append(nums[left] ** 2)
                left = left + 1

        return list(reversed(res_array))

# %% [markdown]
# # Sliding Window

# %% [markdown]
# ### 567. Permutation in String
#
# Given two strings s1 and s2, return true if s2 contains a permutation of s1, or false otherwise.
#
# In other words, return true if one of s1's permutations is the substring of s2.
#
#
# ```
# Example 1:
#
# Input: s1 = "ab", s2 = "eidbaooo"
# Output: true
# Explanation: s2 contains one permutation of s1 ("ba").
# Example 2:
#
# Input: s1 = "ab", s2 = "eidboaoo"
# Output: false
#
# ```
#
# Constraints:
#
# 1 <= s1.length, s2.length <= 104
# s1 and s2 consist of lowercase English letters.

# %%
class Solution:
    def checkInclusion(self, s1: str, s2: str) -> bool:
        '''
        Step 1: Create the target counter for s1 and curr_counter
        Step 2: Fixed window in s2 of size len(s1)
        In loop till we reach end of s2
            Step 3: Add the characters in curr_counter as per the window
                    ( increase the entering element and decrease the leaving element)

            Step 4: Compare the target_counter and curr_counter

        Time complexity : O(m + n) # m is s1 and n is s2
        Space Complexity : O(26) # constant space

        '''

        # edge case handled
        if len(s2) < len(s1):
            return False

        target_counter, curr_counter = defaultdict(int), defaultdict(int)

        for i in range(len(s1)): # it will run n times ( n = len(s1))
            target_counter[s1[i]] += 1
            curr_counter[s2[i]] += 1

        if target_counter == curr_counter:
            return True

        for i in range(len(s1), len(s2)):
            entering_element = s2[i]
            leaving_element = s2[i-len(s1)]

            # updating the curr_counter as per the current window
            curr_counter[entering_element] += 1
            curr_counter[leaving_element] -= 1
            if curr_counter[leaving_element] == 0:
                del curr_counter[leaving_element]
a
            ## compare the curr_counter and target_counter
            if curr_counter == target_counter :  ## max 26 comparisons
                return True

        return False

# %%
from collections import defaultdict

# %%
a = defaultdict(int)

# %%
a
# Out:
# defaultdict(int, {4: 0})

# %%
a[10]
# Out:
# 0

# %%
a
# Out:
# defaultdict(int, {4: 0, 10: 0})

# %%
ord("a") - ord("a")
# Out:
# 0

# %%
ord("b") - ord("a")
# Out:
# 1

# %% [markdown]
# # Binary Search

# %% [markdown]
# ## Leetcode 704. Binary Search

# %% [markdown]
# # Prefix Sum

# %% [markdown]
# ## Leetcode 560. Subarray Sum Equals K

# %%
class Solution:
    def subarraySum(self, nums: List[int], k: int) -> int:
        prefix_seen = {}
        count = 0

        right = 0
        curr_sum = 0
        while right < len(nums):

            prefix_seen[curr_sum] = 1 + prefix_seen.get(curr_sum, 0)
            curr_sum = curr_sum + nums[right]
            if (curr_sum - k) in prefix_seen:
                count = count + prefix_seen[curr_sum - k]

            right = right + 1

        return count
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-363626558.py in <cell line: 0>()
# ----> 1 class Solution:
#       2     def subarraySum(self, nums: List[int], k: int) -> int:
#       3         prefix_seen = {}
#       4         count = 0
#       5
#
# /tmp/ipython-input-363626558.py in Solution()
#       1 class Solution:
# ----> 2     def subarraySum(self, nums: List[int], k: int) -> int:
#       3         prefix_seen = {}
#       4         count = 0
#       5
#
# NameError: name 'List' is not defined

# %%
zoom
from collections import defaultdict

class Solution:
    def subarraySum(self, nums: List[int], k: int) -> int:
        """
        Counts the number of continuous subarrays whose sum equals to k.

        Prefix sum approach:
        Let curr_sum be the running sum at each index.
        If (curr_sum - k) has been seen before, it means there exists a subarray
        ending at the current index with sum k.
        """

        prefix_sum = defaultdict(int)
        prefix_sum[0] = 1  # To account for subarrays that start from index 0

        curr_sum = 0
        count = 0

        for num in nums:
            curr_sum += num

            # Check if there's a subarray ending here that sums to k
            if (curr_sum - k) in prefix_sum:
                count += prefix_sum[curr_sum - k]

            # Record the current prefix sum
            prefix_sum[curr_sum] += 1

        return count

# %% [markdown]
# ## Leetcode 303. Range Sum Query - Immutable

# %%
class NumArray:

    def __init__(self, nums: List[int]):
        ## build the prefixes ( or precalculate the prefixes)
        self.prefix = []
        curr_sum = 0
        for num in nums:
            curr_sum += num
            self.prefix.append(curr_sum)

        # nums = [1, 2, 3] # self.prefix = [0, 1, 3, 6]


    def sumRange(self, left: int, right: int) -> int:
        # use the precalculated prefixes to answer the query
        total = self.prefix[right ]
        left_prefix = self.prefix[left - 1] if left > 0 else 0
        return total - left_prefix

        # adding +1 to the index because self.prefix has one extra 0.



# Your NumArray object will be instantiated and called as such:
# obj = NumArray(nums)
# param_1 = obj.sumRange(left,right)

# %% [markdown]
# # Linked List
#
# <p align="center">
#   <a href="https://youtu.be/ljPbU4f8TX8?si=b0MOgcQR8OKy7_EG" target="_blank">
#     <img src="https://i.ytimg.com/vi/ljPbU4f8TX8/hqdefault.jpg?sqp=-oaymwEnCNACELwBSFryq4qpAxkIARUAAIhCGAHYAQHiAQoIGBACGAY4AUAB&rs=AOn4CLB_31W5LhqVkhcl1spThdHzLpugSw" alt="CodeVerra Channel" width="200"/>
#   </a>
# </p>
#
#
#
# [Watch Linked List - Complete Course](https://youtu.be/ljPbU4f8TX8?si=b0MOgcQR8OKy7_EG)

# %% [markdown]
# ## Leetcode 876. Middle of the Linked List
#
# Given the head of a singly linked list, return the middle node of the linked list.
#
# If there are two middle nodes, return the second middle node.

# %%
# Definition for singly-linked list.
# class ListNode:
#     def __init__(self, val=0, next=None):
#         self.val = val
#         self.next = next
class Solution:
    def middleNode(self, head: Optional[ListNode]) -> Optional[ListNode]:
        '''
        First find the size of the linked list
        position of mid = size // 2
        iterate to the mid
        '''

        ## find the size of the linked list
        curr = head
        size = 0
        while curr :
            size = size + 1
            curr = curr.next

        ## we now have the size

        mid_pos = size // 2

        ## iterate to the middle node
        curr = head
        for _ in range(mid_pos):
            curr = curr.next

        return curr

# %%
# Definition for singly-linked list.
# class ListNode:
#     def __init__(self, val=0, next=None):
#         self.val = val
#         self.next = next
class Solution:
    def middleNode(self, head: Optional[ListNode]) -> Optional[ListNode]:
        '''
        Two pointer approach ( slow and fast pointers)
        '''
        slow, fast = head, head

        while fast and fast.next:
            slow = slow.next ## move the slow pointer 1 step
            fast = fast.next.next ## move the fast pointer 2 steps

        return slow # slow will be at the middle

# %% [markdown]
# ## Leetcode 206. Reverse Linked List
#
# Given the head of a singly linked list, reverse the list, and return the reversed list.

# %%
from typing import Optional

# %%
## Definition for singly-linked list.
class ListNode:
    def __init__(self, val=0, next=None):
        self.val = val
        self.next = next
class Solution:
    def reverseList(self, head: Optional[ListNode]) -> Optional[ListNode]:
        prev = None
        curr = head
        while curr :
            tmp = curr.next
            curr.next = prev

            prev = curr
            curr = tmp
        return prev

# %%
# Definition for singly-linked list.
# class ListNode:
#     def __init__(self, val=0, next=None):
#         self.val = val
#         self.next = next
class Solution:
    def reverseList(self, head: Optional[ListNode]) -> Optional[ListNode]:

        prev = None
        curr = head

        while curr:
            # store the curr.next
            temp = curr.next
            # reverse the connection ( join curr to prev)
            curr.next = prev
            # move the prev ahead
            prev = curr
            # curr to next node(stored in temp)
            curr = temp

        return prev

# %% [markdown]
# ## Leetcode 21. Merge Two Sorted Lists
#
# You are given the heads of two sorted linked lists list1 and list2.
#
# Merge the two lists into one sorted list. The list should be made by splicing together the nodes of the first two lists.
#
# Return the head of the merged linked list.

# %%
# Definition for singly-linked list.
# class ListNode:
#     def __init__(self, val=0, next=None):
#         self.val = val
#         self.next = next

## using dummy node
class Solution:
    def mergeTwoLists(self, list1: Optional[ListNode], list2: Optional[ListNode]) -> Optional[ListNode]:

        dummy = ListNode(-1)
        tail = dummy

        ## iterate on the two lists
        while list1 and list2:
            '''
            compare list1 and list2 value and take the lower value
            and append to dummy
            '''
            if list1.val < list2.val:
                tail.next = list1
                list1 = list1.next
            else:
                tail.next = list2
                list2 = list2.next

            tail = tail.next # update the tail pointer

        '''
        if list1 or list2 is exhausted, then append the other unexhausted
        list to the tail
        '''
        tail.next = list1 if list1 else list2

        return dummy.next

# %%
## without dummy node

# Definition for singly-linked list.
# class ListNode:
#     def __init__(self, val=0, next=None):
#         self.val = val
#         self.next = next
class Solution:
    def mergeTwoLists(self, list1: Optional[ListNode], list2: Optional[ListNode]) -> Optional[ListNode]:

        ####### edge cases #########
        if not list1:
            return list2

        if not list2:
            return list2

        ######### deciding the first node of the answer #########
        if list1.val < list2.val:
            head = list1
            list1 = list1.next

        else:
            head = list2
            list2 = list2.next

        tail = head
        ########################################
        while list1 and list2:
            '''
            compare list1 and list2 value and take the lower value
            and append to dummy
            '''
            if list1.val < list2.val:
                tail.next = list1
                list1 = list1.next
            else:
                tail.next = list2
                list2 = list2.next

            tail = tail.next

        tail.next = list1 if list1 else list2

        return head

# %% [markdown]
# ## Leetcode 141. Linked List Cycle
#
# Given head, the head of a linked list, determine if the linked list has a cycle in it.
#
# There is a cycle in a linked list if there is some node in the list that can be reached again by continuously following the next pointer. Internally, pos is used to denote the index of the node that tail's next pointer is connected to. Note that pos is not passed as a parameter.
#
# Return true if there is a cycle in the linked list. Otherwise, return false.

# %%
# Definition for singly-linked list.
# class ListNode:
#     def __init__(self, x):
#         self.val = x
#         self.next = None

class Solution:
    def hasCycle(self, head: Optional[ListNode]) -> bool:
        '''
        Using Floyd cycle detection using slow and fast pointers
        '''

        ## initialise the slow and fast on head
        slow, fast = head, head
        while fast and fast.next:
            slow = slow.next # moving the slow pointer by 1 step
            fast = fast.next.next # this moves the fast pointer 2 steps

            if slow == fast: # this will happen when there is a cycle
                return True

        return False

# %% [markdown]
# ## Leetcode 83. Remove Duplicates from Sorted List
#
# Given the head of a sorted linked list, delete all duplicates such that each element appears only once. Return the linked list sorted as well.

# %%
# Definition for singly-linked list.
# class ListNode:
#     def __init__(self, val=0, next=None):
#         self.val = val
#         self.next = next
class Solution:
    def deleteDuplicates(self, head: Optional[ListNode]) -> Optional[ListNode]:
        ## start the curr on the head
        curr = head
        while curr and curr.next:  # curr.next
            if curr.val == curr.next.val: ## there is a duplicate next
                curr.next = curr.next.next
            else:
                curr = curr.next

        return head

# %% [markdown]
# ## Leetcode 19. Remove Nth Node From End of List
#
# Given the head of a linked list, remove the nth node from the end of the list and return its head.

# %%
# Definition for singly-linked list.
# class ListNode:
#     def __init__(self, val=0, next=None):
#         self.val = val
#         self.next = next
class Solution:
    def removeNthFromEnd(self, head: Optional[ListNode], n: int) -> Optional[ListNode]:
        dummy = ListNode(-1, head)
        left = right = dummy

        ## move the right pointer n+1 steps
        for _ in range(n+1):
            right  = right.next

        ## now we move left and right together
        while right:
            left = left.next
            right = right.next

        ## now our left pointer is before the node to be deleted
        left.next = left.next.next

        return dummy.next

# %% [markdown]
# ## Leetcode 138. Copy List with Random Pointer
#
# A linked list of length n is given such that each node contains an additional random pointer, which could point to any node in the list, or null.
#
# Construct a deep copy of the list. The deep copy should consist of exactly n brand new nodes, where each new node has its value set to the value of its corresponding original node. Both the next and random pointer of the new nodes should point to new nodes in the copied list such that the pointers in the original list and copied list represent the same list state. None of the pointers in the new list should point to nodes in the original list.
#
# For example, if there are two nodes X and Y in the original list, where X.random --> Y, then for the corresponding two nodes x and y in the copied list, x.random --> y.
#
# Return the head of the copied linked list.
#
# The linked list is represented in the input/output as a list of n nodes. Each node is represented as a pair of [val, random_index] where:
#
# val: an integer representing Node.val
# random_index: the index of the node (range from 0 to n-1) that the random pointer points to, or null if it does not point to any node.
# Your code will only be given the head of the original linked list.

# %%
"""
# Definition for a Node.
class Node:
    def __init__(self, x: int, next: 'Node' = None, random: 'Node' = None):
        self.val = int(x)
        self.next = next
        self.random = random
"""

"""
Time complexity : O(n) ## two passes on given list
Space Complexity : O(n) ## to create the mapping
"""

class Solution:
    def copyRandomList(self, head: 'Optional[Node]') -> 'Optional[Node]':

        if not head: # edge case when the given list is empty
            return None

        ## iterate on the original list and create clones

        curr = head
        mapping = {}

        while curr:
            clone = Node(x = curr.val)
            mapping[curr] = clone
            curr = curr.next


        ## iterate again and create the connection for the cloned nodes

        curr = head
        while curr:
            clone = mapping[curr]
            clone.next = mapping[curr.next] if curr.next else None
            clone.random = mapping[curr.random] if curr.random else None
            curr = curr.next

        return mapping[head]

# %% [markdown]
# ## Leetcode 234. Palindrome Linked List
#
# Given the head of a singly linked list, return true if it is a palindrome or false otherwise.

# %%
# Definition for singly-linked list.
# class ListNode:
#     def __init__(self, val=0, next=None):
#         self.val = val
#         self.next = next
class Solution:
    def isPalindrome(self, head: Optional[ListNode]) -> bool:
        '''
        Brute Force Approach:
            - Collect all the elements of the linked list in an array/ list
            - We will use the two pointer appraoch to check if the list is a palindrome


        Time complexity: O(n)
        Space Complexity: O(n)
        '''

        ## edge cases : if there is only one node or empty
        if not head or not head.next: # linked list is empty or linked list has just one element
            return True


        array = []
        curr = head
        while curr:
            array.append(curr.val)
            curr = curr.next

        ## array now contains all the elements of the linked list

        ## we need to check if the array is a palindrome
        left = 0
        right  = len(array) - 1

        while left < right:
            if array[left] != array[right]:
                return False
            left = left + 1
            right = right - 1

        return True

# %%
# Definition for singly-linked list.
# class ListNode:
#     def __init__(self, val=0, next=None):
#         self.val = val
#         self.next = next
class Solution:
    def isPalindrome(self, head: Optional[ListNode]) -> bool:
        '''
        Optimised approach:
            - find the middle node
            - reverse the second half of the linked list
            - compare the first half and the reversed second half. If they are same return True

        Time  Complexity: O(n)
        Space complexity : O(1)
        '''


        ## edge cases:
        if not head or not head.next:
            return True

        ## Step 1: Find the middle node
        '''
        we will take slow and fast pointers.
        '''
        slow, fast = head, head

        while fast and fast.next:
            slow = slow.next
            fast = fast.next.next

        ## the slow is pointing to the middle of the linked list

        ## Step 2: reverse the 2nd half

        def reverse_linked_list(head):
            prev = None
            curr = head

            while curr:
                temp = curr.next

                curr.next = prev
                prev = curr
                curr = temp

            return prev # head of the  reversed linked list


        second_half = reverse_linked_list(slow)


        ## Step 3: Compare the 1st half and reversed 2nd half

        c1 = head
        c2 = second_half

        while c1 and c2:
            if c1.val != c2.val:
                return False
            c1 = c1.next
            c2 = c2.next

        return True

# %% [markdown]
# # Stack and Queue
#
# [Watch Stack - Complete Course](https://youtu.be/jangL0xiMzU?si=PSi120gpo2-bCOfj)
# <p align="center">
#   <a href="https://youtu.be/jangL0xiMzU?si=PSi120gpo2-bCOfj" target="_blank">
#     <img src="https://i.ytimg.com/vi/jangL0xiMzU/hqdefault.jpg?sqp=-oaymwEnCNACELwBSFryq4qpAxkIARUAAIhCGAHYAQHiAQoIGBACGAY4AUAB&rs=AOn4CLBMtWLnqWkB-87SDp3CIl8M_c12ZQ" alt="CodeVerra Channel" width="200"/>
#   </a>
# </p>
#
#
# [Watch Queue - Complete Course](https://youtu.be/WWcuxFdDalg?si=5Eal6flr5zgpZvq3)
# <p align="center">
#   <a href="https://youtu.be/WWcuxFdDalg?si=5Eal6flr5zgpZvq3" target="_blank">
#     <img src="https://i.ytimg.com/vi/WWcuxFdDalg/hqdefault.jpg?sqp=-oaymwEnCNACELwBSFryq4qpAxkIARUAAIhCGAHYAQHiAQoIGBACGAY4AUAB&rs=AOn4CLCZRkDRTFeXbs-JdXSK2rcHfsYySQ" alt="CodeVerra Channel" width="200"/>
#   </a>
# </p>

# %% [markdown]
# ## Leetcode 20. Valid Parentheses
#
#     Given a string s containing just the characters '(', ')', '{', '}', '[' and ']', determine if the input string is valid.
#
#     An input string is valid if:
#
#     Open brackets must be closed by the same type of brackets.
#     Open brackets must be closed in the correct order.
#     Every close bracket has a corresponding open bracket of the same type.

# %% [markdown]
# ```
# association = {
#     ")" : "(",
#     "}" : "{",
#     "]" : "["
# }
# stack = []
#
# for char in s:
#   if the character is opening:
#       stack.append(char)
#   if the char is closing:
#       then check the previous character (stack.peek())
#       if previous character == association[char] # char is closing
#           stack.pop()
#
#       if previous character != association[char]
#           return False
# ```

# %%
s = "()[]{}"


"() "

'''
if we get a closing bracket then we need to check the last bracket
  - the previous bracket should be open bracket
  - the previous bracket should be the correct open bracket
'''

# %%
class Solution:

    '''
    Time Complexity : O(n)
    Space Complexity : O(n)
    '''
    def isValid(self, s: str) -> bool:

        # create a stack
        stack = []

        mapping = {
                ")": "(",
                "}" : "{",
                "]" : "["
        }

        for character in s:
            if character in mapping : # if s is a closing character
                if not stack or stack[-1] != mapping[character]: # the closing doesnt match the previous character
                    return False
                else: # the brackets are matching
                    stack.pop() # remove the correct opening bracket from the stack

            else: # if s is opening character
                stack.append(character) # we will add the opening character to the stack

        ## in the end if the stack is empty then the string is valid
        return len(stack) == 0

# %% [markdown]
# ## Leetcode 155. Min Stack
#
# Design a stack that supports push, pop, top, and retrieving the minimum element in constant time.
#
# Implement the MinStack class:
#
#     MinStack() initializes the stack object.
#     void push(int val) pushes the element val onto the stack.
#     void pop() removes the element on the top of the stack.
#     int top() gets the top element of the stack.
#     int getMin() retrieves the minimum element in the stack.
#     You must implement a solution with O(1) time complexity for each function.
#
#
# ```
# Example 1:
#
# Input
# ["MinStack","push","push","push","getMin","pop","top","getMin"]
# [[],[-2],[0],[-3],[],[],[],[]]
#
# Output
# [null,null,null,null,-3,null,0,-2]
#
# Explanation
# MinStack minStack = new MinStack();
# minStack.push(-2);
# minStack.push(0);
# minStack.push(-3);
# minStack.getMin(); // return -3
# minStack.pop();
# minStack.top();    // return 0
# minStack.getMin(); // return -2
# ```

# %%
class MinStack:

    def __init__(self):
        '''
        initialise a main_stack and helper_stack
        '''
        self.main_stack = []
        self.helper_stack = [] # this will be used to track the minimum


    def push(self, val: int) -> None:
        '''
        we will push to the main stack and also update the helper stack
        if the val is lesser than current minimum, then val is the new minumum
        '''

        # first we can add to the main_stack
        self.main_stack.append(val)
        if not self.helper_stack or val < self.helper_stack[-1]: # val is the new minumum
            self.helper_stack.append(val) # update the new minimum
        else:
            self.helper_stack.append(self.helper_stack[-1])

    def pop(self) -> None:
        # if not self.main_stack:
        #     raise Exception("stack is empty!")
        self.main_stack.pop() # pop from main_stack
        self.helper_stack.pop() # pop from helper_stack

    def top(self) -> int:
        return self.main_stack[-1]


    def getMin(self) -> int:
        '''
        helper_stack stores the minimum value corresponding to every element in main stack
        '''
        return self.helper_stack[-1]



# Your MinStack object will be instantiated and called as such:
# obj = MinStack()
# obj.push(val)
# obj.pop()
# param_3 = obj.top()
# param_4 = obj.getMin()

# %%
x = [[1, 2, 3], [4, 5, 6]]
nested_list = [1,[2,[3,[4,5]]],6]

def flatten(nested_list):
  # result = []
  for element in nested_list:
    if isinstance(element, list):
      yield (flatten(element))
    else:
      yield element

list(flatten(nested_list))


# flatten = lambda nested_list : ()

# %% [markdown]
# ## Leetcode 496. Next Greater Element I
#
# The next greater element of some element x in an array is the first greater element that is to the right of x in the same array.
#
# You are given two distinct 0-indexed integer arrays nums1 and nums2, where nums1 is a subset of nums2.
#
# For each 0 <= i < nums1.length, find the index j such that nums1[i] == nums2[j] and determine the next greater element of nums2[j] in nums2. If there is no next greater element, then the answer for this query is -1.
#
# Return an array ans of length nums1.length such that ans[i] is the next greater element as described above.
#
#
# ```
# Example 1:
#
# Input: nums1 = [4,1,2], nums2 = [1,3,4,2]
# Output: [-1,3,-1]
# Explanation: The next greater element for each value of nums1 is as follows:
# - 4 is underlined in nums2 = [1,3,4,2]. There is no next greater element, so the answer is -1.
# - 1 is underlined in nums2 = [1,3,4,2]. The next greater element is 3.
# - 2 is underlined in nums2 = [1,3,4,2]. There is no next greater element, so the answer is -1.
# ```

# %%
class Solution:
    def nextGreaterElement(self, nums1: List[int], nums2: List[int]) -> List[int]:
        result = {} # to store the nge for nums2
        stack = []

        for (ind, val) in enumerate(nums2):
            while stack and val > stack[-1][1]:
                i,v = stack.pop()
                result[v] = val
            stack.append((ind, val))

        ## we have the nge for nums2
        '''
        nums2 = [1, 3, 4, 2]
        result = {1: 3, 3: 4}


        we need the nge for nums1. (nums1 is a subset of nums 2)
        '''

        nge = []
        for num in nums1:
            nge.append(result.get(num, -1))

        return nge

# %% [markdown]
# ## Leetcode 232. Implement Queue using Stacks
#
# Implement a first in first out (FIFO) queue using only two stacks. The implemented queue should support all the functions of a normal queue (push, peek, pop, and empty).
#
# Implement the MyQueue class:
#
#     void push(int x) Pushes element x to the back of the queue.
#     int pop() Removes the element from the front of the queue and returns it.
#     int peek() Returns the element at the front of the queue.
#     boolean empty() Returns true if the queue is empty, false otherwise.
#     Notes:
#
# You must use only standard operations of a stack, which means only push to top, peek/pop from top, size, and is empty operations are valid.
# Depending on your language, the stack may not be supported natively. You may simulate a stack using a list or deque (double-ended queue) as long as you use only a stack's standard operations.

# %%
class MyQueue:

    def __init__(self):
        self.main_stack = []
        self.helper_stack = []


    def push(self, x: int) -> None:
        self.main_stack.append(x)


    def pop(self) -> int:
        '''
        if helper is not empty, then pop from helper stack and return
        else: empty all elements from main to helper and then pop
        '''

        if not self.helper_stack:
            # transfer all elements of main stack to helper stack
            while self.main_stack:
                self.helper_stack.append(self.main_stack.pop())
        return self.helper_stack.pop()


    def peek(self) -> int:
        if not self.helper_stack:
            # transfer all elements of main stack to helper stack
            while self.main_stack:
                self.helper_stack.append(self.main_stack.pop())
        return self.helper_stack[-1]


    def empty(self) -> bool:
        if self.main_stack or self.helper_stack:
            return False
        else:
            return True



# Your MyQueue object will be instantiated and called as such:
# obj = MyQueue()
# obj.push(x)
# param_2 = obj.pop()
# param_3 = obj.peek()
# param_4 = obj.empty()

# %% [markdown]
# ## Leetcode 225. Implement Stack using Queues
#
# Implement a last-in-first-out (LIFO) stack using only two queues. The implemented stack should support all the functions of a normal stack (push, top, pop, and empty).
#
# Implement the MyStack class:
#
# void push(int x) Pushes element x to the top of the stack.
# int pop() Removes the element on the top of the stack and returns it.
# int top() Returns the element on the top of the stack.
# boolean empty() Returns true if the stack is empty, false otherwise.
# Notes:
#
# You must use only standard operations of a queue, which means that only push to back, peek/pop from front, size and is empty operations are valid.
# Depending on your language, the queue may not be supported natively. You may simulate a queue using a list or deque (double-ended queue) as long as you use only a queue's standard operations.
#
# ```
# Example 1:
#
# Input
# ["MyStack", "push", "push", "top", "pop", "empty"]
# [[], [1], [2], [], [], []]
# Output
# [null, null, null, 2, 2, false]
#
# Explanation
# MyStack myStack = new MyStack();
# myStack.push(1);
# myStack.push(2);
# myStack.top(); // return 2
# myStack.pop(); // return 2
# myStack.empty(); // return False
# ```

# %%
class MyStack:

    def __init__(self):
        self.main_queue = deque()
        self.helper_queue = deque()


    def push(self, x: int) -> None:
        '''
        push to helper stack
        we will dequeue all elements from main queue and add to helper queue
        swap the main and helper queue
        '''
        self.helper_queue.append(x)

        while self.main_queue:
            self.helper_queue.append(self.main_queue.popleft())

        self.main_queue, self.helper_queue = self.helper_queue, self.main_queue

    def pop(self) -> int:

        return self.main_queue.popleft()


    def top(self) -> int:
        return self.main_queue[0]


    def empty(self) -> bool:
        return len(self.main_queue) == 0



# Your MyStack object will be instantiated and called as such:
# obj = MyStack()
# obj.push(x)
# param_2 = obj.pop()
# param_3 = obj.top()
# param_4 = obj.empty()

# %%
class MyStack:

    def __init__(self):
        self.main_queue = deque()


    def push(self, x: int) -> None:

        self.main_queue.append(x)

        # write a loop to dequeue all the elements before x and enqueue it back

        for _ in range(len(self.main_queue) -1):
            self.main_queue.append(self.main_queue.popleft())

    def pop(self) -> int:

        return self.main_queue.popleft()


    def top(self) -> int:
        return self.main_queue[0]


    def empty(self) -> bool:
        return len(self.main_queue) == 0



# Your MyStack object will be instantiated and called as such:
# obj = MyStack()
# obj.push(x)
# param_2 = obj.pop()
# param_3 = obj.top()
# param_4 = obj.empty()

# %% [markdown]
# # Trees

# %% [markdown]
# ## Leetcode 144. Binary Tree Preorder Traversal
#
# Given the root of a binary tree, return the preorder traversal of its nodes' values.

# %%
# Definition for a binary tree node.
# class TreeNode:
#     def __init__(self, val=0, left=None, right=None):
#         self.val = val
#         self.left = left
#         self.right = right
class Solution:
    def preorderTraversal(self, root: Optional[TreeNode]) -> List[int]:

        '''
        iterative solution using stack ( DFS -> stack )
        '''

        if not root:
            return []

        stack = [root]
        result = []

        while stack:
            node = stack.pop()

            ## visit the node
            result.append(node.val)

            ## dfs on left node first and then right node
            if node.right:  # pushing right first and then left so that left is on top of stack
                stack.append(node.right)

            if node.left:
                stack.append(node.left)

        return result

# %%
# Definition for a binary tree node.
# class TreeNode:
#     def __init__(self, val=0, left=None, right=None):
#         self.val = val
#         self.left = left
#         self.right = right
class Solution:
    def preorderTraversal(self, root: Optional[TreeNode]) -> List[int]:

        '''
        Recursive approach
        '''
        result = []

        def dfs(node):
            if not node:  # base case
                return

            result.append(node.val) # root node
            dfs(node.left) # left node
            dfs(node.right) # right node

        dfs(root)
        return result
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-2958162596.py in <cell line: 0>()
#       5 #         self.left = left
#       6 #         self.right = right
# ----> 7 class Solution:
#       8     def preorderTraversal(self, root: Optional[TreeNode]) -> List[int]:
#       9
#
# /tmp/ipython-input-2958162596.py in Solution()
#       6 #         self.right = right
#       7 class Solution:
# ----> 8     def preorderTraversal(self, root: Optional[TreeNode]) -> List[int]:
#       9
#      10         '''
#
# NameError: name 'Optional' is not defined

# %%
def factorial(n):
  print(f"calling factorial({n})")
  if n == 0:
    return 1
  return n * factorial (n-1)

factorial(3)
# Out:
# calling factorial(3)
# calling factorial(2)
# calling factorial(1)
# calling factorial(0)
# 6

# %% [markdown]
# ## Leetcode 94. Binary Tree Inorder Traversal
#
# Given the root of a binary tree, return the inorder traversal of its nodes' values.

# %%
# Definition for a binary tree node.
# class TreeNode:
#     def __init__(self, val=0, left=None, right=None):
#         self.val = val
#         self.left = left
#         self.right = right
class Solution:
    def inorderTraversal(self, root: Optional[TreeNode]) -> List[int]:

        '''
        Recursive code
        '''

        result = []

        def dfs(node):
            if not node:
                return

            ## dfs on left
            dfs(node.left)
            ## visit the node
            result.append(node.val)
            ## dfs on right
            dfs(node.right)


        dfs(root)
        return result

# %% [markdown]
# ## Leetcode 145. Binary Tree Postorder Traversal
#
# Given the root of a binary tree, return the postorder traversal of its nodes' values.

# %%
# Definition for a binary tree node.
# class TreeNode:
#     def __init__(self, val=0, left=None, right=None):
#         self.val = val
#         self.left = left
#         self.right = right
class Solution:
    def postorderTraversal(self, root: Optional[TreeNode]) -> List[int]:

        result = []

        def dfs(node):

            if not node:
                return

            dfs(node.left)
            dfs(node.right)
            result.append(node.val)

        dfs(root)
        return result

# %%
from typing import List, Optional, Sequence

# %%
def add(x : int, y : int) -> int:
  '''
  This function will add two numbers x and y

  Params:
    x: number 1 to be added
    y: number 2 to be added

  Returns:
    sum of x and y
  '''

  return (x+y)

add(4, 5)
# Out:
# 9

# %% [markdown]
# ## Leetcode 100. Same Tree
#
# Given the roots of two binary trees p and q, write a function to check if they are the same or not.
#
# Two binary trees are considered the same if they are structurally identical, and the nodes have the same value.

# %%
# Definition for a binary tree node.
# class TreeNode:
#     def __init__(self, val=0, left=None, right=None):
#         self.val = val
#         self.left = left
#         self.right = right
class Solution:
    def isSameTree(self, p: Optional[TreeNode], q: Optional[TreeNode]) -> bool:
        if not p and not q:
            return True

        if (not p and q) or (p and not q):
            return False

        if p.val != q.val :
            return False

        # if p and q are equal then check for left and right subtrees are both equal
        return self.isSameTree(p.left, q.left) and self.isSameTree(p.right, q.right)

# %% [markdown]
# ## Leetcode 112. Path Sum
#
# Given the root of a binary tree and an integer targetSum, return true if the tree has a root-to-leaf path such that adding up all the values along the path equals targetSum.
#
# A leaf is a node with no children.

# %%
# Definition for a binary tree node.
# class TreeNode:
#     def __init__(self, val=0, left=None, right=None):
#         self.val = val
#         self.left = left
#         self.right = right
class Solution:
    def hasPathSum(self, root: Optional[TreeNode], targetSum: int) -> bool:
        '''
        Time Complexity : O(n)
        Space Complexity: O(1)
        '''
        ## if there is not root
        if not root:
            return False

        ## if there are not children
        if not root.right and not root.left:
            return root.val == targetSum

        ## otherwise check if either left or right subtree is having a pathsum of remainder
        remainder = targetSum - root.val

        return self.hasPathSum(root.left, remainder) or self.hasPathSum(root.right, remainder)

# %% [markdown]
# ## Leetcode 226. Invert Binary Tree
#
# Given the root of a binary tree, invert the tree, and return its root.

# %%
# Definition for a binary tree node.
# class TreeNode:
#     def __init__(self, val=0, left=None, right=None):
#         self.val = val
#         self.left = left
#         self.right = right
class Solution:
    def invertTree(self, root: Optional[TreeNode]) -> Optional[TreeNode]:
        if not root:
            return None

        ## swap the left and right children
        root.left, root.right = root.right, root.left

        ## invert the child trees
        self.invertTree(root.left)
        self.invertTree(root.right)

        return root

# %% [markdown]
# ## Leetcode 102. Binary Tree Level Order Traversal
#
# Given the root of a binary tree, return the level order traversal of its nodes' values. (i.e., from left to right, level by level).

# %%
# Definition for a binary tree node.
# class TreeNode:
#     def __init__(self, val=0, left=None, right=None):
#         self.val = val
#         self.left = left
#         self.right = right
class Solution:
    def levelOrder(self, root: Optional[TreeNode]) -> List[List[int]]:

        if not root:
            return []

        queue  = deque([root])
        result = []

        while queue:
            level = []
            size = len(queue)
            for _ in range(size):
                node = queue.popleft()
                level.append(node.val)
                if node.left:
                    queue.append(node.left)
                if node.right:
                    queue.append(node.right)

            result.append(level)

        return result

# %% [markdown]
# ## Leetcode 101. Symmetric Tree
#
# Given the root of a binary tree, check whether it is a mirror of itself (i.e., symmetric around its center).

# %%
# Definition for a binary tree node.
# class TreeNode:
#     def __init__(self, val=0, left=None, right=None):
#         self.val = val
#         self.left = left
#         self.right = right
class Solution:
    def isSymmetric(self, root: Optional[TreeNode]) -> bool:
        '''
        Time Complexity : O(n)
        Space Complexity : O(h) # h is the height of the tree
        '''

        def mirror(left, right):
            if not left and not right: # both nodes are absent
                return True
            if not left or not right:  # one of the nodes are absent
                return False
            if left.val != right.val: # both nodes present but values unequal
                return False

            ## if the nodes are present and values are equal then check if the children are symmetric
            return mirror(left.left, right.right) \
            and mirror(left.right, right.left)

        return mirror(root.left, root.right)

# %% [markdown]
# ## Leetcode 199. Binary Tree Right Side View
#
# Given the root of a binary tree, imagine yourself standing on the right side of it, return the values of the nodes you can see ordered from top to bottom.

# %%
# Definition for a binary tree node.
# class TreeNode:
#     def __init__(self, val=0, left=None, right=None):
#         self.val = val
#         self.left = left
#         self.right = right
class Solution:
    def rightSideView(self, root: Optional[TreeNode]) -> List[int]:
        if not root:
            return []

        queue = deque([root])
        result = []

        while queue:
            level = []
            size = len(queue)
            for _ in range(size):
                node = queue.popleft() # dequeue from a queue
                level.append(node.val)
                # add the child nodes to the queue
                if node.left :
                    queue.append(node.left)
                if node.right:
                    queue.append(node.right)

            result.append(level)

        # we will take last node from every level
        return [x[-1] for x in result]

# %%
# Definition for a binary tree node.
# class TreeNode:
#     def __init__(self, val=0, left=None, right=None):
#         self.val = val
#         self.left = left
#         self.right = right
class Solution:
    def rightSideView(self, root: Optional[TreeNode]) -> List[int]:
        if not root:
            return []

        queue = deque([root])
        result = []

        while queue:
            last_seen = None
            size = len(queue)
            for _ in range(size):
                node = queue.popleft() # dequeue from a queue
                last_seen = node.val # keep track of only the last node from each level
                # add the child nodes to the queue
                if node.left :
                    queue.append(node.left)
                if node.right:
                    queue.append(node.right)

            result.append(last_seen)

        return result

# %% [markdown]
# ## Leetcode 104. Maximum Depth of Binary Tree
#
# Given the root of a binary tree, return its maximum depth.
#
# A binary tree's maximum depth is the number of nodes along the longest path from the root node down to the farthest leaf node.

# %%
# Definition for a binary tree node.
# class TreeNode:
#     def __init__(self, val=0, left=None, right=None):
#         self.val = val
#         self.left = left
#         self.right = right
class Solution:
    def maxDepth(self, root: Optional[TreeNode]) -> int:
        '''
        Recursive solution

        maxdepth(node) = 1 + max(maxdepth(node.left), maxdepth(node.right))
        '''

        # base case
        if not  root :
            return 0

        return  1 + max(self.maxDepth(root.left), self.maxDepth(root.right))

# %%
'''
Max depth of a tree using BFS
'''

# Definition for a binary tree node.
# class TreeNode:
#     def __init__(self, val=0, left=None, right=None):
#         self.val = val
#         self.left = left
#         self.right = right
class Solution:
    def maxDepth(self, root: Optional[TreeNode]) -> int:
        if not root:
            return 0

        queue = deque([root])
        result = []
        level = 0
        while queue:
            level = level + 1
            size = len(queue)
            for _ in range(size):
                node = queue.popleft() # dequeue from a queue
                # level.append(node.val)
                # add the child nodes to the queue
                if node.left :
                    queue.append(node.left)
                if node.right:
                    queue.append(node.right)
            # result.append(level)
        # we will take last node from every level
        return level
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-1638221522.py in <cell line: 0>()
#       9 #         self.left = left
#      10 #         self.right = right
# ---> 11 class Solution:
#      12     def maxDepth(self, root: Optional[TreeNode]) -> int:
#      13         if not root:
#
# /tmp/ipython-input-1638221522.py in Solution()
#      10 #         self.right = right
#      11 class Solution:
# ---> 12     def maxDepth(self, root: Optional[TreeNode]) -> int:
#      13         if not root:
#      14             return 0
#
# NameError: name 'Optional' is not defined

# %% [markdown]
# ## Leetcode 637. Average of Levels in Binary Tree

# %% [markdown]
# ## Leetcode 103. Binary Tree Zigzag Level Order Traversal

# %% [markdown]
# ## Leetcode 700. Search in a Binary Search Tree

# %%
# Definition for a binary tree node.
# class TreeNode:
#     def __init__(self, val=0, left=None, right=None):
#         self.val = val
#         self.left = left
#         self.right = right
class Solution:
    def searchBST(self, root: Optional[TreeNode], val: int) -> Optional[TreeNode]:

        '''
        iterative approach
        '''
        curr = root
        while curr:
            if val == curr.val:
                return curr
            elif val < curr.val:
                curr = curr.left
            else:
                curr = curr.right
        return None

# %%
# Definition for a binary tree node.
# class TreeNode:
#     def __init__(self, val=0, left=None, right=None):
#         self.val = val
#         self.left = left
#         self.right = right
class Solution:
    def searchBST(self, root: Optional[TreeNode], val: int) -> Optional[TreeNode]:

        '''
         recursive approach
        '''

        if not root:
            return None

        if root.val == val:
            return root

        elif val > root.val:
            return self.searchBST(root.right, val)

        else:
            return self.searchBST(root.left, val)

# %% [markdown]
# ## Leetcode 701. Insert into a Binary Search Tree

# %% [markdown]
# ## Leetcode 103. Binary Tree Zigzag Level Order Traversal
#
# Given the root of a binary tree, return the zigzag level order traversal of its nodes' values. (i.e., from left to right, then right to left for the next level and alternate between).

# %%
# Definition for a binary tree node.
# class TreeNode:
#     def __init__(self, val=0, left=None, right=None):
#         self.val = val
#         self.left = left
#         self.right = right
class Solution:
    def zigzagLevelOrder(self, root: Optional[TreeNode]) -> List[List[int]]:

        # edge cases
        if not root:
            return []

        res = [ ]
        queue = deque([root])
        reverse_flag = 0
        while queue:
            size = len(queue)
            level = []
            for _ in range(size):
                node = queue.popleft() # dequeue
                level.append(node.val)

                if node.left:
                    queue.append(node.left)
                if node.right:
                    queue.append(node.right)
            if reverse_flag:
                level.reverse()
            reverse_flag = not reverse_flag
            res.append(level)

        return res

# %%
# Definition for a binary tree node.
# class TreeNode:
#     def __init__(self, val=0, left=None, right=None):
#         self.val = val
#         self.left = left
#         self.right = right
class Solution:
    def zigzagLevelOrder(self, root: Optional[TreeNode]) -> List[List[int]]:
        '''
        Time complexity : O(n)
        Space Complexity: O(n)
        '''
        # edge cases
        if not root:
            return []

        res = [ ]
        queue = deque([root])
        reverse_flag = 0
        while queue:
            size = len(queue)
            level = deque()
            for _ in range(size):
                node = queue.popleft() # dequeue
                if reverse_flag: #
                    level.appendleft(node.val)
                else:
                    level.append(node.val)

                if node.left:
                    queue.append(node.left)
                if node.right:
                    queue.append(node.right)
            # if reverse_flag:
            #     level.reverse()
            reverse_flag = not reverse_flag
            res.append(list(level))

        return res

# %% [markdown]
# ## Leetcode 230. Kth Smallest Element in a BST
#
# Given the root of a binary search tree, and an integer k, return the kth smallest value (1-indexed) of all the values of the nodes in the tree.

# %%
# Definition for a binary tree node.
# class TreeNode:
#     def __init__(self, val=0, left=None, right=None):
#         self.val = val
#         self.left = left
#         self.right = right
class Solution:
    def kthSmallest(self, root: Optional[TreeNode], k: int) -> int:
        '''
        We are traversing the entire tree inorder then taking the kth element
        from the inorder traversal.
        A more efficient approach is to just traverse k elements and do a early exit.
        '''
        res = []
        def dfs(node):

            if not node:
                return

            ## left node
            dfs(node.left)
            ## root
            res.append(node.val)
            ## right node
            dfs(node.right)

        dfs(root)
        # print(res)
        return res[k-1]

# %%
# Definition for a binary tree node.
# class TreeNode:
#     def __init__(self, val=0, left=None, right=None):
#         self.val = val
#         self.left = left
#         self.right = right
class Solution:
    def kthSmallest(self, root: Optional[TreeNode], k: int) -> int:
        '''
        Inorder traversal of a BST gives the values of the tree in sorted manner
        '''
        res = []
        def dfs(node):
            if not node:
                return
            if len(res) == k: # early exit once k elements are collected
                return
            ## left node
            dfs(node.left)
            ## root
            if len(res) < k :
                res.append(node.val)
            ## right node
            dfs(node.right)

        dfs(root)
        # print(res)
        return res[-1]

# %% [markdown]
# ## Leetcode 637. Average of Levels in Binary Tree
#
# Given the root of a binary tree, return the average value of the nodes on each level in the form of an array. Answers within 10-5 of the actual answer will be accepted.

# %%
# Definition for a binary tree node.
# class TreeNode:
#     def __init__(self, val=0, left=None, right=None):
#         self.val = val
#         self.left = left
#         self.right = right
class Solution:
    def averageOfLevels(self, root: Optional[TreeNode]) -> List[float]:
        queue = deque([root])
        res = []

        while queue:
            size = len(queue)
            level = []

            for _ in range(size):
                node = queue.popleft()
                level.append(node.val)

                if node.left:
                    queue.append(node.left)
                if node.right:
                    queue.append(node.right)

            res.append(sum(level)/len(level))

        return res

# %%
# Definition for a binary tree node.
# class TreeNode:
#     def __init__(self, val=0, left=None, right=None):
#         self.val = val
#         self.left = left
#         self.right = right
class Solution:
    def averageOfLevels(self, root: Optional[TreeNode]) -> List[float]:
        queue = deque([root])
        res = []

        while queue:
            size = len(queue)
            level_sum = 0

            for _ in range(size):
                node = queue.popleft()
                level_sum  = level_sum + node.val

                if node.left:
                    queue.append(node.left)
                if node.right:
                    queue.append(node.right)

            res.append(level_sum/size)

        return res

# %% [markdown]
# ## Leetcode 111. Minimum Depth of Binary Tree
#
# Given a binary tree, find its minimum depth.
#
# The minimum depth is the number of nodes along the shortest path from the root node down to the nearest leaf node.
#
# Note: A leaf is a node with no children.

# %%
# Definition for a binary tree node.
# class TreeNode:
#     def __init__(self, val=0, left=None, right=None):
#         self.val = val
#         self.left = left
#         self.right = right
class Solution:
    def minDepth(self, root: Optional[TreeNode]) -> int:
        ## edge case
        if not root:
            return 0

        # no children ( leaf node)
        if not root.left and not root.right:
            return 1

        # only one child
        if  not root.right:
            return 1 + self.minDepth(root.left)
        if  not root.left:
            return 1 + self.minDepth(root.right)


        # if both children are present
        return 1 + min(self.minDepth(root.left), self.minDepth(root.right))

# %%
# Definition for a binary tree node.
# class TreeNode:
#     def __init__(self, val=0, left=None, right=None):
#         self.val = val
#         self.left = left
#         self.right = right
class Solution:
    def minDepth(self, root: Optional[TreeNode]) -> int:
        '''
        BFS or level order traversal approach
        '''
        ## edge case
        if not root:
            return 0

        queue = deque([(root, 1)])
        # level = 1
        while queue:
            size = len(queue)
            for _ in range(size):
                node, level = queue.popleft() # dequeue

                if not node.left and not node.right:
                    return level
                if node.left:
                    queue.append((node.left, level + 1))
                if node.right:
                    queue.append((node.right, level + 1))

# %%
# Definition for a binary tree node.
# class TreeNode:
#     def __init__(self, val=0, left=None, right=None):
#         self.val = val
#         self.left = left
#         self.right = right
class Solution:
    def minDepth(self, root: Optional[TreeNode]) -> int:
        '''
        BFS or level order traversal approach
        '''
        ## edge case
        if not root:
            return 0

        queue = deque([root])
        level = 0
        while queue:
            size = len(queue)
            level = level + 1
            for _ in range(size):
                node = queue.popleft() # dequeue
                if not node.left and not node.right:
                    return level
                if node.left:
                    queue.append(node.left)
                if node.right:
                    queue.append(node.right)

# %% [markdown]
# ## Leetcode 572. Subtree of Another Tree
#
# Given the roots of two binary trees root and subRoot, return true if there is a subtree of root with the same structure and node values of subRoot and false otherwise.
#
# A subtree of a binary tree tree is a tree that consists of a node in tree and all of this node's descendants. The tree tree could also be considered as a subtree of itself.

# %%
# Definition for a binary tree node.
# class TreeNode:
#     def __init__(self, val=0, left=None, right=None):
#         self.val = val
#         self.left = left
#         self.right = right
class Solution:
    def isSubtree(self, root: Optional[TreeNode], subRoot: Optional[TreeNode]) -> bool:

        def sameTree(p, q):
            '''
            Returns True if p and q are same trees

            Time Complexity: O(n)
            Space Complexity: O(h) where h is height --> O(logN) if tree is balanced
            if skewed then O(h) -> O(n)
            '''
            if not p and not q: # if both p and q are none ( empty trees)
                return True

            if not p or not q: # if one tree is empty and other is not
                return False

            if p.val != q.val: # both trees are non empty but root values are unequal
                return False


            return sameTree(p.left, q.left) and sameTree(p.right, q.right)


        if root and not subRoot:
            return True
        if not root and subRoot:
            return False

        if sameTree(root, subRoot):
            return True

        return self.isSubtree(root.left, subRoot) or self.isSubtree(root.right, subRoot)

# %%
# Definition for a binary tree node.
# class TreeNode:
#     def __init__(self, val=0, left=None, right=None):
#         self.val = val
#         self.left = left
#         self.right = right
class Solution:
    def isSubtree(self, root: Optional[TreeNode], subRoot: Optional[TreeNode]) -> bool:

        def serialize(root):
            if not root:
                return "#"
            return "->" + str(root.val) + serialize(root.left) + serialize(root.right)

        root_serialized = serialize(root)
        subroot_serialized = serialize(subRoot)

        return subroot_serialized in root_serialized

# %% [markdown]
# ## Leetcode 543. Diameter of Binary Tree
#
# Given the root of a binary tree, return the length of the diameter of the tree.
#
# The diameter of a binary tree is the length of the longest path between any two nodes in a tree. This path may or may not pass through the root.
#
# The length of a path between two nodes is represented by the number of edges between them.

# %%
# Definition for a binary tree node.
# class TreeNode:
#     def __init__(self, val=0, left=None, right=None):
#         self.val = val
#         self.left = left
#         self.right = right
class Solution:
    def diameterOfBinaryTree(self, root: Optional[TreeNode]) -> int:

        '''
        Time Complexity: O(n)
        Space Complexity : O(h)
        '''
        self.diameter = 0

        def height(node):
            '''
            This function will return the max_height of the node
            '''
            ## base case
            if not node:
                return 0

            left_max_length = height(node.left)
            right_max_length = height(node.right)

            diameter_of_node = left_max_length + right_max_length
            self.diameter = max(self.diameter, diameter_of_node)

            return 1 + max(left_max_length, right_max_length )

        height(root)
        return self.diameter

# %% [markdown]
# # Graphs

# %% [markdown]
# ## Depth First Search (DFS) - Iterative

# %%
graph = {
    'A': ['B', 'C'],
    'B': ['A', 'D', 'E'],
    'C': ['A', 'F'],
    'D': ['B'],
    'E': ['B', 'F'],
    'F': ['C', 'E']
}

# %%
def dfs(start_node, graph):
  visited = set()
  res = []
  stack = [start_node]

  while stack:
    node = stack.pop()
    if node not in visited:
      visited.add(node)
      res.append(node)
      neighbors = graph[node]
      for nei in neighbors:
        if nei not in visited:
          stack.append(nei)
  return res

dfs(start_node = "A" , graph = graph)
# Out:
# ['A', 'C', 'F', 'E', 'B', 'D']

# %% [markdown]
# ## Depth First Search (DFS) - Recursive

# %% [markdown]
# ## Breadth First Search (BFS) - Iterative using Queue

# %%
from collections import deque

def bfs(start_node, graph):
  queue = deque([start_node])
  visited = {start_node}
  res = []

  while queue:
    node = queue.popleft()
    # if node not in visited:
      # visited.add(node)
    res.append(node)

    neighbors = graph[node]
    for nei in neighbors:
      if nei not in visited:
        visited.add(nei)
        queue.append(nei)

  return res

bfs("A", graph)
# Out:
# ['A', 'B', 'C', 'D', 'E', 'F']

# %%
## Assignment: try to find the separate levels in the graph

# %%
from collections import deque

def bfs(start_node, graph):
  queue = deque([start_node])
  visited = {start_node}
  res = []

  while queue:
    size = len(queue)
    level = []

    for _ in range(size):
      node = queue.popleft()
      # print("popped node", node)
      level.append(node)
      neighbors = graph[node]
      for nei in neighbors:
        if nei not in visited:
          visited.add(nei)
          queue.append(nei)
    res.append(level)
  return res

graph = {

         1:[2, 3, 4],
         2:[5],
         3:[7, 8],
         4:[],
         5:[3, 4, 6],
         6:[],
         7:[6 ],
         8:[1]

}


bfs(1, graph)
# Out:
# [[1], [2, 3, 4], [5, 7, 8], [6]]

# %%
my_set = {1}

# %%
my_set
# Out:
# {1}

# %%
set("A")
# Out:
# {'A'}

# %% [markdown]
# ## Leetcode 200. Number of Islands
#
# Given an m x n 2D binary grid grid which represents a map of '1's (land) and '0's (water), return the number of islands.
#
# An island is surrounded by water and is formed by connecting adjacent lands horizontally or vertically. You may assume all four edges of the grid are all surrounded by water.

# %%
class Solution:
    def numIslands(self, grid: List[List[str]]) -> int:

        def bfs(row, col):
            queue = deque()
            queue.append((row, col))
            grid[row][col] = "0" # mark it as seen

            while queue:
                r, c = queue.popleft()
                neighbors = [(r+1,c), (r-1,c), (r, c+1), (r, c-1)]
                for nr, nc in neighbors:
                    ## check if nei is valid ( in bounds and is land)
                    if 0 <= nr < rows and 0 <= nc < cols and grid[nr][nc] == "1":
                        grid[nr][nc] = "0"
                        queue.append((nr, nc))

        island_count = 0
        rows, cols = len(grid), len(grid[0])
        for row in range(rows):
            for col in range(cols):
                if grid[row][col] == "1":
                    island_count += 1
                    bfs(row, col)

        return island_count

# %%
class Solution:
    def numIslands(self, grid: List[List[str]]) -> int:
        def dfs(row, col):
            # print("running dfs on ", row, col)
            # check if invalid
            if 0 <= row < rows and 0 <= col < cols and grid[row][col] == "1":
                grid[row][col] = "0" # mark it as seen
                # print("marked as seen:", row, col)
                neighbors = [(row+1,col), (row-1,col), (row, col+1), (row, col-1)]
                for nr, nc in neighbors:
                    dfs(nr, nc)

        island_count = 0
        rows, cols = len(grid), len(grid[0])
        for row in range(rows):
            for col in range(cols):
                if grid[row][col] == "1":
                    island_count += 1
                    dfs(row, col)

        return island_count

# %% [markdown]
# ## Leetcode 733. Flood Fill
#
# You are given an image represented by an m x n grid of integers image, where image[i][j] represents the pixel value of the image. You are also given three integers sr, sc, and color. Your task is to perform a flood fill on the image starting from the pixel image[sr][sc].
#
# To perform a flood fill:
#
# Begin with the starting pixel and change its color to color.
# Perform the same process for each pixel that is directly adjacent (pixels that share a side with the original pixel, either horizontally or vertically) and shares the same color as the starting pixel.
# Keep repeating this process by checking neighboring pixels of the updated pixels and modifying their color if it matches the original color of the starting pixel.
# The process stops when there are no more adjacent pixels of the original color to update.
# Return the modified image after performing the flood fill.

# %%
class Solution:
    def floodFill(self, image: List[List[int]], sr: int, sc: int, color: int) -> List[List[int]]:
        '''
        DFS Based solution
        '''

        starting_cell_color = image[sr][sc]

        ## if the starting_color == color
        if starting_cell_color == color:
            return image

        rows, cols = len(image), len(image[0])
        def dfs(row, col):
            '''
            Replace the neighboring cells to new_color
            '''

            ## check for valid

            if 0 <= row < rows and 0<= col < cols and image[row][col] == starting_cell_color:
                ## mark it as seen
                image[row][col] = color # convert to new color

                neighbors = [(row+1, col), (row-1, col), (row, col+1), (row, col-1) ]
                for nr, nc in neighbors:
                    dfs(nr, nc)

        dfs(sr, sc)
        return image

# %% [markdown]
# ## Leetcode 207. Course Schedule
# \
# There are a total of numCourses courses you have to take, labeled from 0 to numCourses - 1. You are given an array prerequisites where prerequisites[i] = [ai, bi] indicates that you must take course bi first if you want to take course ai.
#
# For example, the pair [0, 1], indicates that to take course 0 you have to first take course 1.
# Return true if you can finish all courses. Otherwise, return false.

# %%
class Solution:
    def canFinish(self, numCourses: int, prerequisites: List[List[int]]) -> bool:

        ## convert edge list to  adjacency list
        courses  = defaultdict(list)
        for a, b in prerequisites:
            courses[a].append(b)

        # print(courses)
        UNSEEN = 0
        CHECKING = 1
        DONE = 2

        status_list = [UNSEEN] * numCourses

        def dfs(ind):
            status = status_list[ind]
            if status == CHECKING:
                return False

            if status == DONE:
                return True

            status_list[ind] = CHECKING
            for prereq in courses[ind]:
                if not dfs(prereq):
                    return False

            status_list[ind] = DONE
            return True

        for ind in range(numCourses):
            if status_list[ind] == UNSEEN:
                if not dfs(ind):
                    return False

        return True

# %% [markdown]
# ## Leetcode 417. Pacific Atlantic Water Flow
#
# There is an m x n rectangular island that borders both the Pacific Ocean and Atlantic Ocean. The Pacific Ocean touches the island's left and top edges, and the Atlantic Ocean touches the island's right and bottom edges.
#
# The island is partitioned into a grid of square cells. You are given an m x n integer matrix heights where heights[r][c] represents the height above sea level of the cell at coordinate (r, c).
#
# The island receives a lot of rain, and the rain water can flow to neighboring cells directly north, south, east, and west if the neighboring cell's height is less than or equal to the current cell's height. Water can flow from any cell adjacent to an ocean into the ocean.
#
# Return a 2D list of grid coordinates result where result[i] = [ri, ci] denotes that rain water can flow from cell (ri, ci) to both the Pacific and Atlantic oceans.

# %%
class Solution:
    def pacificAtlantic(self, heights: List[List[int]]) -> List[List[int]]:
        pacific_queue = deque()
        pacific_seen = set()

        atlantic_queue = deque()
        atlantic_seen = set()

        m, n = len(heights), len(heights[0])

        for i in range(n):
            pacific_queue.append((0, i))
            pacific_seen.add((0, i))
        for i in range(m):
            pacific_queue.append((i, 0))
            pacific_seen.add((i, 0))

        for i in range(n):
            atlantic_queue.append((m-1, i))
            atlantic_seen.add((m-1, i))
        for i in range(m):
            atlantic_queue.append((i, n-1))
            atlantic_seen.add((i, n-1))


        def get_reachable_cells(queue, seen):
            reachable = set()
            while queue:
                r, c = queue.popleft()
                reachable.add((r,c))
                neighbors = [(r+1, c), (r-1, c), (r, c+1), (r, c-1)]
                for nr, nc in neighbors:
                    ## check if valid
                    if (0 <= nr < m) and (0 <= nc < n) \
                    and (nr, nc) not in reachable \
                    and heights[nr][nc] >=heights[r][c]:
                        seen.add((nr, nc))
                        queue.append((nr, nc))
            return reachable

        pacific_reachable = get_reachable_cells(pacific_queue, pacific_seen)
        atlantic_reachable =get_reachable_cells(atlantic_queue, atlantic_seen )

        print(pacific_reachable, atlantic_reachable)

        return list(pacific_reachable.intersection(atlantic_reachable))

# %% [markdown]
# # Heap

# %%
import heapq

# %%
nums = [3, 10, -12, 15, 100, 0, 2]
heapq.heapify(nums) # O(n)

nums # min-heap by default
# Out:
# [-12, 10, 0, 15, 100, 3, 2]

# %%
heapq.heappop(nums)
# Out:
# -12

# %%
nums
# Out:
# [0, 10, 2, 15, 100, 3]

# %%
heapq.heappush(nums, -500)

# %%
nums
# Out:
# [-500, 10, 0, 15, 100, 3, 2]

# %%
### Find most frequent element in a list
from collections import Counter

nums = [2, 3, 4, 5, 1, 1, 1, 2, 2, 3, 3, 3, 3, 3, 3, 3]

freq_dict = Counter(nums)
freq_dict

## sort this dictionary based on values

## we can use a heap
heap = []

for (val, freq) in freq_dict.items():
  heapq.heappush(heap, (freq, val))

heap
# Out:
# [(1, 4), (1, 5), (3, 2), (8, 3), (3, 1)]

# %%
heap = []

for (val, freq) in freq_dict.items():
  heapq.heappush(heap, (-freq, val))

heap
# Out:
# [(-8, 3), (-3, 1), (-1, 4), (-1, 5), (-3, 2)]

# %%
heap = []

for (val, freq) in freq_dict.items():
  heapq.heappush(heap, (-freq, val))

heap


## heap sort
sorted_array = []
size = len(heap)
for _ in range(size):
  sorted_array.append(heapq.heappop(heap)[1])

# %%
sorted_array
# Out:
# [3, 1, 2, 4, 5]
