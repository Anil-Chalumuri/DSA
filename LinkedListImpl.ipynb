# %% [markdown]
# # Linked List
# # Creating a Node with data and add

# %%
class Node:
    def __init__(self,data):
        self.data = data
        self.next = None

# %% [markdown]
# ## Creating a Linked List with all functionality

# %%
      
class Node:
    def __init__(self,data):
        self.data = data
        self.next = None

class LinkedList:
    def __init__(self):
        self.head = None
        self.size = 0
    
    def is_empty(self):
        return self.size ==0

    def append(self, val):
        '''  
        Case 1: If the Linked list is empty then assign the new node as head
        Case 2: If there are existing elements, then traverse to tail and set new node after tail
        '''
        new_node = Node(val)

        if self.is_empty():
            self.head = new_node
        else:
            curr = self.head
            while curr.next:
                curr = curr.next
            curr.next = new_node
        # Increase the size of the Linked list after adding new node in the list
        self.size += 1

    def __repr__(self):
        list_of_elements = self._traverse()
        return "-> ".join([str(x) for x in list_of_elements]) + " -> None"
        

    
    def _traverse(self):
        if self.is_empty():
            return []
        element = []
        curr = self.head
        while curr:
            element.append(curr.data)
            curr = curr.next
        return element

# %%
mylist = LinkedList()

# %%
mylist.append(10)

# %%
mylist.__repr__()
# Out:
# '10 -> None'

# %%
mylist.append(20)
mylist.append(30)
mylist.append(40)
mylist.append(50)

# %%
mylist.__repr__()
# Out:
# '10-> 20-> 30-> 40-> 50 -> None'

# %% [markdown]
# # LinkedList with insert functionality
#  Potential Edge cases
#  1) Position of Insertion is valid
#  2) Is linked list empty
#  3) Linkedlist is having one element
#  4) While Inserting/deleting if postion is zero

# %%
# Insert functionality
def insert(self,position,val):
    # if position is invalid: 
        # raise exception
        node = Node(val)
        # Inset at begining if postion is first(zero position)
        if position == 0:
            node.next = self.head
            self.head = node
        else:
            curr = self.head
            for _ in range(position -1):
                curr = curr.next
            node.next = curr.next
            curr.next = node
        self.size +=1

# %%
class Node:
    def __init__(self,data):
        self.data = data
        self.next = None
      
class LinkedList:
    def __init__(self):
        self.head = None
        self.size = 0
    
    def is_empty(self):
        return self.size ==0

    def append(self, val):
        '''  
        Case 1: If the Linked list is empty then assign the new node as head
        Case 2: If there are existing elements, then traverse to tail and set new node after tail
        '''
        new_node = Node(val)

        if self.is_empty():
            self.head = new_node
        else:
            curr = self.head
            while curr.next:
                curr = curr.next
            curr.next = new_node
        # Increase the size of the Linked list after adding new node in the list
        self.size += 1

    def __repr__(self):
        list_of_elements = self._traverse()
        return "-> ".join([str(x) for x in list_of_elements]) + " -> None"
        

    
    def _traverse(self):
        if self.is_empty():
            return []
        element = []
        curr = self.head
        while curr:
            element.append(curr.data)
            curr = curr.next
        return element
    
    def insert(self,position,val):
     
     if position < 0  or position > self.size: 
        raise IndexError("The position is invalid!!")
     node = Node(val)
    # Inset at begining if postion is first(zero position)
     if position == 0:
        node.next = self.head
        self.head = node
     else:
        curr = self.head
        for _ in range(position -1):
            curr = curr.next
        node.next = curr.next
        curr.next = node
     self.size +=1

# %%
mylist1 = LinkedList()
mylist1.append(10)
mylist1.append(20)
mylist1.append(30)
mylist1.append(40)
mylist1.append(50)
print("created a Linked List")
# Out:
# created a Linked List

# %%
mylist1.__repr__()
# Out:
# '10-> 20-> 30-> 40-> 50 -> None'

# %%
mylist1.insert(2,25)

# %%
mylist1.__repr__()
# Out:
# '10-> 20-> 25-> 30-> 40-> 50 -> None'

# %%
mylist1.insert(0,5)

# %%
mylist1.__repr__()
# Out:
# '5-> 10-> 20-> 25-> 30-> 40-> 50 -> None'

# %%
mylist1.size
# Out:
# 7

# %%
mylist1.insert(-1,3)
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[28], line 1
# ----> 1 mylist1.insert(-1,3)
#
# Cell In[19], line 50, in LinkedList.insert(self, position, val)
#      47 def insert(self,position,val):
#      49  if position < 0  or position > self.size:
# ---> 50     raise IndexError("The position is invalid!!")
#      51  node = Node(val)
#      52 # Inset at begining if postion is first(zero position)
#
# IndexError: The position is invalid!!

# %%
mylist1.insert(6,45)

# %%
mylist1.__repr__()
# Out:
# '5-> 10-> 20-> 25-> 30-> 40-> 45-> 50 -> None'

# %%
mylist1.insert(9,60)
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[31], line 1
# ----> 1 mylist1.insert(9,60)
#
# Cell In[19], line 50, in LinkedList.insert(self, position, val)
#      47 def insert(self,position,val):
#      49  if position < 0  or position > self.size:
# ---> 50     raise IndexError("The position is invalid!!")
#      51  node = Node(val)
#      52 # Inset at begining if postion is first(zero position)
#
# IndexError: The position is invalid!!

# %% [markdown]
# # LinkedList with Delete functionality
#  Potential Edge cases
#  1) Position of Deletion is  position < 0 || position >= size
#  2) Is position ==0
#  3) If size of LinkedList =1

# %%
    #raise Exception("Linkedlist is empty!!")

# %%
def delete(self,position):
    if position < 0 or position >= self.size: 
        raise IndexError("The position is invalid!!")
        
    if self.size ==1:
        self.head = None
        # Delete at begining if position is zero position
    elif position == 0:
        curr = self.head
        self.head  = curr.next
            
    else:
        curr = self.head
        for _ in range(position -1):
            curr = curr.next
        curr.next = curr.next.next
            
    self.size -=1

# %%
class Node:
    def __init__(self,data):
        self.data = data
        self.next = None
      
class LinkedList:
    def __init__(self):
        self.head = None
        self.size = 0
    
    def is_empty(self):
        return self.size ==0

    def append(self, val):
        '''  
        Case 1: If the Linked list is empty then assign the new node as head
        Case 2: If there are existing elements, then traverse to tail and set new node after tail
        '''
        new_node = Node(val)

        if self.is_empty():
            self.head = new_node
        else:
            curr = self.head
            while curr.next:
                curr = curr.next
            curr.next = new_node
        # Increase the size of the Linked list after adding new node in the list
        self.size += 1

    def __repr__(self):
        list_of_elements = self._traverse()
        return "-> ".join([str(x) for x in list_of_elements]) + " -> None"
        

    
    def _traverse(self):
        if self.is_empty():
            return []
        element = []
        curr = self.head
        while curr:
            element.append(curr.data)
            curr = curr.next
        return element
    
    def insert(self,position,val):
     
     if position < 0  or position > self.size: 
        raise IndexError("The position is invalid!!")
     node = Node(val)
    # Inset at begining if postion is first(zero position)
     if position == 0:
        node.next = self.head
        self.head = node
     else:
        curr = self.head
        for _ in range(position -1):
            curr = curr.next
        node.next = curr.next
        curr.next = node
     self.size +=1
    
    def delete(self,position):
        if position < 0 or position >= self.size: 
            raise IndexError("The position is invalid!!")
        
        if self.size ==1:
            self.head = None
        # Delete at begining if position is zero position
        elif position == 0:
            curr = self.head
            self.head  = curr.next
            
        else:
            curr = self.head
            for _ in range(position -1):
                curr = curr.next
            curr.next = curr.next.next
            
        self.size -=1

# %%
mylist2 = LinkedList()
mylist2.append(10)
mylist2.append(20)
mylist2.append(30)
mylist2.append(40)
mylist2.append(50)
print("created a Linked List with Delete Functionality")
# Out:
# created a Linked List with Delete Functionality

# %%
mylist2.__repr__()
# Out:
# '10-> 20-> 30-> 40-> 50 -> None'

# %%
mylist2.delete(0)

# %%
mylist2.__repr__()
# Out:
# '20-> 30-> 40-> 50 -> None'

# %%
mylist2.delete(2)

# %%
mylist2.__repr__()
# Out:
# '20-> 30-> 50 -> None'

# %%
mylist2.delete(-1)
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[39], line 1
# ----> 1 mylist2.delete(-1)
#
# Cell In[32], line 66, in LinkedList.delete(self, position)
#      64 def delete(self,position):
#      65     if position < 0 or position >= self.size:
# ---> 66         raise IndexError("The position is invalid!!")
#      68     if self.size ==1:
#      69         self.head = None
#
# IndexError: The position is invalid!!

# %%
mylist2.size
# Out:
# 3

# %%
mylist2.delete(4)
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[45], line 1
# ----> 1 mylist2.delete(4)
#
# Cell In[32], line 66, in LinkedList.delete(self, position)
#      64 def delete(self,position):
#      65     if position < 0 or position >= self.size:
# ---> 66         raise IndexError("The position is invalid!!")
#      68     if self.size ==1:
#      69         self.head = None
#
# IndexError: The position is invalid!!

# %%
## Saved the LinkedList functionality
